# %% [markdown]
# #GRAPH5
# 인접 행렬을 사용한다. 대부분값이 채워지고 두 정점 연결 여부를 빠르게 확인 가능하기 때문이다.

# %% [markdown]
# #GRAPH6
# 간선이 매우 적은 희소 그래프이므로 인접 리스트를 사용하는 것이 좋다. 존재하는 간선만 저장하고 메모리 절약이 가능하기 때문이다.

# %% [markdown]
# #GRAPH8
# DFS(x)의 호출 횟수는: 시작 정점 1에서 방문 가능한 정점 수

# %% [markdown]
# #GRAPH12
# (1) 프림 알고리즘
# 선택 간선 순서:
# D-C(1)
# C-H(2)
# D-E(3)
# H-G(4)
# H-F(5)
# A-B(8)
# B-D(9)
# 최소 신장 트리 가중치 합: 1 + 2 + 3 + 4 + 5 + 8 + 9 = 32

# %% [markdown]
# #GRAPH12
# (2) 크루스칼 알고리즘
# 가중치 작은 순으로 선택:
# D-C(1)
# C-H(2)
# D-E(3)
# H-G(4)
# H-F(5)
# A-B(8)
# B-D(9)
# 최소 신장 트리 가중치 합:32

# %% [markdown]
# #GRAPH16
# TopologicalSort(G):
#     indegree 계산
#
#     indegree가 0인 정점을 stack에 push
#
#     while stack이 비어있지 않음:
#         v = pop()
#         출력
#
#         for 모든 인접 정점 u:
#             indegree[u]--
#
#             if indegree[u] == 0:
#                 push(u)
#
#
# 가능한 위상 정렬 개수: 5가지

# %% [markdown]
# #GRAPH17
# 초기값:Q=0, 나머지=∞
# Q선택:
# A=10
# C=7
# E=4
#
# E선택:
# C=min(7,4+2)=6
# F=12
# G=24
#
# C선택:
# A=min(10,6+2)=8
# B=14
#
# A선택: B=min(14,8+8)=14
#
# B선택: D=26
#
# F선택: D=min(26,12+7)=19
#
# D선택: G=min(24,19+4)=23
#
# G선택: 최종 종료
# 최종 최단 거리:
# Q = 0
# A = 8
# B = 14
# C = 6
# D = 19
# E = 4
# F = 12
# G = 23

# %% [markdown]
# #GRAPH18
# A → B = 1,
# A → C = 2,
# C → B = -5

# %% [markdown]
# #GRAPH22
# 음수 사이클이 존재하는 경우

# %% [markdown]
# #SORTING 5
# (1) 선택정렬
# [12 70 30 20 55 25]
# [12 20 30 70 55 25]
# [12 20 25 70 55 30]
# [12 20 25 30 55 70]
# [12 20 25 30 55 70]
#
# (2)버블정렬
# [12 70 30 20 55 25]
# [12 30 20 55 25 70]
# [12 20 30 25 55 70]
# [12 20 25 30 55 70]
# [12 20 25 30 55 70]
#
# (3)삽입정렬
# [12 70 30 20 55 25]
# [12 30 70 20 55 25]
# [12 20 30 70 55 25]
# [12 20 30 55 70 25]
# [12 20 25 30 55 70]

# %% [markdown]
# #SORTING6
#
# (1)병합정렬
# 분할:
# [12 70 30 20] [55 25 40 50]
#
# [12 70] [30 20] [55 25] [40 50]
#
# [12][70] [30][20] [55][25] [40][50]
#
# 병합:
# [12 70]
# [20 30]
# [25 55]
# [40 50]
#
# [12 20 30 70]
# [25 40 50 55]
#
# [12 20 25 30 40 50 55 70]
#
# (2) 힙 정렬
# 최대 힙 생성:
# [70 55 50 20 12 25 40 30]
#
# 정렬:
# [55 30 50 20 12 25 40 70]
# [50 30 40 20 12 25 55 70]
# [40 30 25 20 12 50 55 70]
# [30 20 25 12 40 50 55 70]
# [25 20 12 30 40 50 55 70]
# [20 12 25 30 40 50 55 70]
# [12 20 25 30 40 50 55 70]
#
# (3)퀵 정렬
# 초기:
# [12 70 30 20 55 25 40 50]
# 분할:
# [12 | 70 30 20 55 25 40 50]
# 오른쪽 부분 정렬:
# [20 25 30 40 50 55 70]
# 최종 결과:
# [12 20 25 30 40 50 55 70]
