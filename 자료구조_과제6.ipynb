# %% [markdown]
# 1.(1) 7, 17, 70
# (2) 2*2*2= 8개
# (3)전체 노드=15, 리프=8, 내부 노드:7
# 8-7=1
# (4)항상 성립한다.

# %% [markdown]
# 2.(1) n+1/2
# (2) 리프= 내부+1

# %% [markdown]
# 3.(1) 5,3,1,8,7,6,9
# (2)1,3,5,6,7,8,9
# (3)1,3,6,7,9,8,5
# (4)h=1. T는 단 1개의 노드를 갖는다. 유일한 노드를 방문하는 것은 당연히 정렬된 순서디아.
# 가정: k<h 인 모든 k에 대해 성립한다 가정한다.
# 전개: r의 왼쪽 노드는 T(l), 오른쪽 노드는 T(r) 이다. 귀납적 과정에 의해 중위 순회는 T(l)과 T(r)을 각각 정렬된 순서로 방문한다. T(l)의 모든 키는 r의 키보다 작고, T(r)의 모든 키는 r의 키보다 크므로 중위 순회 T(l)->r-> T(r)은 정렬된 순서이다.

# %% [markdown]
# 4. 55 (30 < 55) → 왼쪽
# 15 (30 > 15) → 오른쪽
# 28 (30 > 28) → 오른쪽
# 30 → 찾음

# %% [markdown]
# 5.
#
#             55
#           /    \
#         15      60
#        /  \       \
#       8   28       90
#      /   /  \
#     3   18   30
#        /       \
#       16        48

# %% [markdown]
# 6.
#
#             55
#           /    \
#         15      60
#        /  \       \
#       8   28       90
#      /      \
#     3        48
#             /  \
#            33   50
#           /  \
#          32  36

# %% [markdown]
# 7.
#
#             55
#           /    \
#         15      60
#        /  \       \
#       8   28       90
#             \
#              48
#             /  \
#           38    50
#          /
#         33
#        /  \
#       32  36

# %% [markdown]
# 8.
#
#             55
#           /    \
#         28      60
#        /  \       \
#       8   48       90
#      /   /  \
#     3   38   50
#        /
#       33
#      /  \
#     32  36

# %% [markdown]
# 9. 최대높이: h=n, 최소 높이: h=⌊log2​n⌋+1
